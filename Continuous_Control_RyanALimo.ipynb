# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %%
import torch 
from collections import deque 

import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import Agent

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name="Reacher.app")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
#reset the env
env_info = env.reset(train_mode=True)[brain_name]
# num. of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)
# Size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)
# examine the state space
states = env_info.vector_observations
state_size = states.shape[1]
print('there are {} agents, each observes a state w/ length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])

# # reset the environment
# env_info = env.reset(train_mode=True)[brain_name]

# # number of agents
# num_agents = len(env_info.agents)
# print('Number of agents:', num_agents)

# # size of each action
# action_size = brain.vector_action_space_size
# print('Size of each action:', action_size)

# examine the state space 
# states = env_info.vector_observations
# state_size = states.shape[1]
# Out:
# Number of agents: 1
# Size of each action: 4
# there are 1 agents, each observes a state w/ length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
# env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
# states = env_info.vector_observations                  # get the current state (for each agent)
# scores = np.zeros(num_agents)                          # initialize the score (for each agent)
# while True:
#     actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#     actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#     env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#     next_states = env_info.vector_observations         # get next state (for each agent)
#     rewards = env_info.rewards                         # get reward (for each agent)
#     dones = env_info.local_done                        # see if episode finished
#     scores += env_info.rewards                         # update the score (for each agent)
#     states = next_states                               # roll over states to next time step
#     if np.any(dones):                                  # exit loop if episode finished
#         break
# print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.20999999530613422

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
# env = UnityEnvironment(file_name="Reacher.app")

def DDPG(num_episodes=200, maxTime = 200):
    mean_score = []
    score_deque = deque(maxlen=100)
    scores = np.zeros(num_agents)
    time_steps = 20
    update = 10
    
    solved = False 
    env_info = env.reset(train_mode=True)[brain_name]
    env_info = env.reset(train_mode=True)[brain_name]
    
    states = env_info.vector_observations
    
    agent_tuple = {"state_size": state_size, "action_size": action_size, "random_seed":2,}
    agents = [Agent(**agent_tuple) for _ in range(num_agents)]
    action = [agent.act(state[i]) for i, agent in enumerate(agents)]
    
    for i_episode in range(1,num_episodes+1):
        states = env_info.vector_observations
        for agent in agents:
            agent.reset()
            
        for t in range(maxTime):
            actions = [agent.act(states[i]) for i, agent in enumerate(agents)]
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = env_info.local_done
#           step
            step_t = zip(agents, states, actions, rewards, next_states, dones)
    #         
            for agent, state, action, reward, next_step, done in step_t:
                agent.memory.add(state, action, reward, next_step, done)
                if (t % time_steps == 0):
                    agent.step(state, action, reward, next_step, done, update)
            states = next_states
            scores += rewards
            if np.any(dones):
                break
            score = np.mean(scores)
            mean_score.append(score)
            scores_deque.append(score)
            mean = np.mean(scores_deque)
        print('\r Episode {} \t Average score: {:.2f} \n'.format(i_episode, mean))

        if not solved and np.mean(scores_deque) > 30.0:
            print('\r Env. solced @ i_episode={}, with mean_score={:.2f}\r'.format(i_episode, mean))
            solved = True
    torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
    torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
    
    return mean_score
            
        
def DDPG(num_episodes=250, max_t=450):
    avg_score = []
    scores_deque = deque(maxlen=100)
    scores = np.zeros(num_agents)
    time_steps = 20
    update = 10
    
    solved = False
    env_info = env.reset(train_mode=True)[brain_name]
    
    states = env_info.vector_observations
    
    agent_tuple = {"state_size": state_size, "action_size": action_size, "random_seed": 2,}
    agents = [Agent(**agent_tuple) for _ in range(num_agents)]
    action = [agent.act(states[i]) for i, agent in enumerate(agents)]   
    
    for i_episode in range(1, num_episodes+1):
        states = env_info.vector_observations                 
        for agent in agents:
            agent.reset()

        for t in range(max_t):
            actions = [agent.act(states[i]) for i, agent in enumerate(agents)]            
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations         
            rewards = env_info.rewards                         
            dones = env_info.local_done                       
            
            step_t = zip(agents, states, actions, rewards, next_states, dones)
            
            for agent, state, action, reward, next_step, done in step_t:
                agent.memory.add(state, action, reward, next_step, done)
                if ( t % time_steps == 0):
                    agent.step(state, action, reward, next_step, done, update)
            states  = next_states
            scores += rewards                                  
            if np.any(dones):                                 
                break
                
        score = np.mean(scores)        
        avg_score.append(score)
        scores_deque.append(score)
        avg = np.mean(scores_deque)            
            
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, avg,), end="\n")

        if not solved and np.mean(scores_deque) > 30.:
            print("\r\rEnviroment solved in @ i_episode={i_episode}, w/ avg_score={avg:.2f}\r".format(i_episode=i_episode, avg=avg))
            solved= True

    torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
    torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
    
    return avg_score

# %%
#         print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, avg,), end="\n")

#         if not solved and np.mean(scores_deque) > 30.:
#             print("\r\rEnviroment solved in @ i_episode={i_episode}, w/ avg_score={avg:.2f}\r".format(i_episode=i_episode, avg=avg))
#             solved= True
# # 
#     torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
#     torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
    
#     return avg_score

# %%
scores = DDPG()
# Out:
# Episode 1	Average Score: 0.00
# Episode 2	Average Score: 0.00
# Episode 3	Average Score: 0.00
# Episode 4	Average Score: 0.09
# Episode 5	Average Score: 0.16
# Episode 6	Average Score: 0.23
# Episode 7	Average Score: 0.34
# Episode 8	Average Score: 0.43
# Episode 9	Average Score: 0.51
# Episode 10	Average Score: 0.56
# Episode 11	Average Score: 0.64
# Episode 12	Average Score: 0.70
# Episode 13	Average Score: 0.76
# Episode 14	Average Score: 0.83
# Episode 15	Average Score: 0.91
# Episode 16	Average Score: 1.00
# Episode 17	Average Score: 1.09
# Episode 18	Average Score: 1.17
# Episode 19	Average Score: 1.29
# Episode 20	Average Score: 1.43
# Episode 21	Average Score: 1.56
# Episode 22	Average Score: 1.68
# Episode 23	Average Score: 1.80
# Episode 24	Average Score: 1.91
# Episode 25	Average Score: 2.03
# Episode 26	Average Score: 2.13
# Episode 27	Average Score: 2.24
# Episode 28	Average Score: 2.35
# Episode 29	Average Score: 2.45
# Episode 30	Average Score: 2.55
# Episode 31	Average Score: 2.65
# Episode 32	Average Score: 2.75
# Episode 33	Average Score: 2.84
# Episode 34	Average Score: 2.94
# Episode 35	Average Score: 3.06
# Episode 36	Average Score: 3.16
# Episode 37	Average Score: 3.27
# Episode 38	Average Score: 3.37
# Episode 39	Average Score: 3.47
# Episode 40	Average Score: 3.57
# Episode 41	Average Score: 3.67
# Episode 42	Average Score: 3.77
# Episode 43	Average Score: 3.87
# Episode 44	Average Score: 3.97
# Episode 45	Average Score: 4.07
# Episode 46	Average Score: 4.19
# Episode 47	Average Score: 4.30
# Episode 48	Average Score: 4.40
# Episode 49	Average Score: 4.51
# Episode 50	Average Score: 4.64
# Episode 51	Average Score: 4.75
# Episode 52	Average Score: 4.86
# Episode 53	Average Score: 4.99
# Episode 54	Average Score: 5.11
# Episode 55	Average Score: 5.22
# Episode 56	Average Score: 5.34
# Episode 57	Average Score: 5.45
# Episode 58	Average Score: 5.56
# Episode 59	Average Score: 5.66
# Episode 60	Average Score: 5.76
# Episode 61	Average Score: 5.86
# Episode 62	Average Score: 5.97
# Episode 63	Average Score: 6.08
# Episode 64	Average Score: 6.18
# Episode 65	Average Score: 6.28
# Episode 66	Average Score: 6.39
# Episode 67	Average Score: 6.49
# Episode 68	Average Score: 6.60
# Episode 69	Average Score: 6.70
# Episode 70	Average Score: 6.81
# Episode 71	Average Score: 6.91
# Episode 72	Average Score: 7.02
# Episode 73	Average Score: 7.12
# Episode 74	Average Score: 7.23
# Episode 75	Average Score: 7.33
# Episode 76	Average Score: 7.44
# Episode 77	Average Score: 7.54
# Episode 78	Average Score: 7.64
# Episode 79	Average Score: 7.75
# Episode 80	Average Score: 7.85
# Episode 81	Average Score: 7.95
# Episode 82	Average Score: 8.05
# Episode 83	Average Score: 8.15
# Episode 84	Average Score: 8.25
# Episode 85	Average Score: 8.35
# Episode 86	Average Score: 8.45
# Episode 87	Average Score: 8.55
# Episode 88	Average Score: 8.65
# Episode 89	Average Score: 8.75
# Episode 90	Average Score: 8.85
# Episode 91	Average Score: 8.95
# Episode 92	Average Score: 9.05
# Episode 93	Average Score: 9.15
# Episode 94	Average Score: 9.25
# Episode 95	Average Score: 9.34
# Episode 96	Average Score: 9.43
# Episode 97	Average Score: 9.52
# Episode 98	Average Score: 9.61
# Episode 99	Average Score: 9.70
# Episode 100	Average Score: 9.79
# Episode 101	Average Score: 9.98
# Episode 102	Average Score: 10.17
# Episode 103	Average Score: 10.36
# Episode 104	Average Score: 10.55
# Episode 105	Average Score: 10.74
# Episode 106	Average Score: 10.93
# Episode 107	Average Score: 11.12
# Episode 108	Average Score: 11.30
# Episode 109	Average Score: 11.49
# Episode 110	Average Score: 11.68
# Episode 111	Average Score: 11.87
# Episode 112	Average Score: 12.06
# Episode 113	Average Score: 12.24
# Episode 114	Average Score: 12.43
# Episode 115	Average Score: 12.62
# Episode 116	Average Score: 12.80
# Episode 117	Average Score: 12.98
# Episode 118	Average Score: 13.17
# Episode 119	Average Score: 13.35
# Episode 120	Average Score: 13.53
# Episode 121	Average Score: 13.70
# Episode 122	Average Score: 13.88
# Episode 123	Average Score: 14.05
# Episode 124	Average Score: 14.23
# Episode 125	Average Score: 14.41
# Episode 126	Average Score: 14.58
# Episode 127	Average Score: 14.75
# Episode 128	Average Score: 14.92
# Episode 129	Average Score: 15.09
# Episode 130	Average Score: 15.26
# Episode 131	Average Score: 15.43
# Episode 132	Average Score: 15.60
# Episode 133	Average Score: 15.78
# Episode 134	Average Score: 15.95
# Episode 135	Average Score: 16.12
# Episode 136	Average Score: 16.28
# Episode 137	Average Score: 16.45
# Episode 138	Average Score: 16.62
# Episode 139	Average Score: 16.78
# Episode 140	Average Score: 16.96
# Episode 141	Average Score: 17.12
# Episode 142	Average Score: 17.29
# Episode 143	Average Score: 17.46
# Episode 144	Average Score: 17.62
# Episode 145	Average Score: 17.79
# Episode 146	Average Score: 17.95
# Episode 147	Average Score: 18.11
# Episode 148	Average Score: 18.27
# Episode 149	Average Score: 18.43
# Episode 150	Average Score: 18.58
# Episode 151	Average Score: 18.73
# Episode 152	Average Score: 18.89
# Episode 153	Average Score: 19.03
# Episode 154	Average Score: 19.18
# Episode 155	Average Score: 19.33
# Episode 156	Average Score: 19.47
# Episode 157	Average Score: 19.62
# Episode 158	Average Score: 19.77
# Episode 159	Average Score: 19.92
# Episode 160	Average Score: 20.07
# Episode 161	Average Score: 20.22
# Episode 162	Average Score: 20.36
# Episode 163	Average Score: 20.51
# Episode 164	Average Score: 20.66
# Episode 165	Average Score: 20.81
# Episode 166	Average Score: 20.95
# Episode 167	Average Score: 21.10
# Episode 168	Average Score: 21.25
# Episode 169	Average Score: 21.40
# Episode 170	Average Score: 21.55
# Episode 171	Average Score: 21.70
# Episode 172	Average Score: 21.86
# Episode 173	Average Score: 22.01
# Episode 174	Average Score: 22.16
# Episode 175	Average Score: 22.32
# Episode 176	Average Score: 22.47
# Episode 177	Average Score: 22.62
# Episode 178	Average Score: 22.77
# Episode 179	Average Score: 22.93
# Episode 180	Average Score: 23.08
# Episode 181	Average Score: 23.23
# Episode 182	Average Score: 23.39
# Episode 183	Average Score: 23.55
# Episode 184	Average Score: 23.71
# Episode 185	Average Score: 23.87
# Episode 186	Average Score: 24.03
# Episode 187	Average Score: 24.19
# Episode 188	Average Score: 24.34
# Episode 189	Average Score: 24.50
# Episode 190	Average Score: 24.66
# Episode 191	Average Score: 24.81
# Episode 192	Average Score: 24.96
# Episode 193	Average Score: 25.12
# Episode 194	Average Score: 25.28
# Episode 195	Average Score: 25.43
# Episode 196	Average Score: 25.59
# Episode 197	Average Score: 25.75
# Episode 198	Average Score: 25.90
# Episode 199	Average Score: 26.06
# Episode 200	Average Score: 26.22
# Episode 201	Average Score: 26.38
# Episode 202	Average Score: 26.55
# Episode 203	Average Score: 26.71
# Episode 204	Average Score: 26.87
# Episode 205	Average Score: 27.03
# Episode 206	Average Score: 27.20
# Episode 207	Average Score: 27.36
# Episode 208	Average Score: 27.53
# Episode 209	Average Score: 27.69
# Episode 210	Average Score: 27.85
# Episode 211	Average Score: 28.01
# Episode 212	Average Score: 28.17
# Episode 213	Average Score: 28.34
# Episode 214	Average Score: 28.51
# Episode 215	Average Score: 28.67
# Episode 216	Average Score: 28.83
# Episode 217	Average Score: 29.00
# Episode 218	Average Score: 29.16
# Episode 219	Average Score: 29.33
# Episode 220	Average Score: 29.49
# Episode 221	Average Score: 29.66
# Episode 222	Average Score: 29.82
# Episode 223	Average Score: 29.98
# Episode 224	Average Score: 30.14
# Enviroment solved in @ i_episode=224, w/ avg_score=30.14
# Episode 225	Average Score: 30.31
# Episode 226	Average Score: 30.47
# Episode 227	Average Score: 30.64
# Episode 228	Average Score: 30.80
# Episode 229	Average Score: 30.97
# Episode 230	Average Score: 31.13
# Episode 231	Average Score: 31.30
# Episode 232	Average Score: 31.48
# Episode 233	Average Score: 31.65
# Episode 234	Average Score: 31.82
# Episode 235	Average Score: 32.00
# Episode 236	Average Score: 32.18
# Episode 237	Average Score: 32.37
# Episode 238	Average Score: 32.55
# Episode 239	Average Score: 32.74
# Episode 240	Average Score: 32.92
# Episode 241	Average Score: 33.10
# Episode 242	Average Score: 33.29
# Episode 243	Average Score: 33.47
# Episode 244	Average Score: 33.65
# Episode 245	Average Score: 33.83
# Episode 246	Average Score: 34.01
# Episode 247	Average Score: 34.19
# Episode 248	Average Score: 34.37
# Episode 249	Average Score: 34.55
# Episode 250	Average Score: 34.73

# %%
t = np.arange(1,len(scores)+1)
plt.plot(t, scores, color="blue", linewidth=2.5, linestyle="-")
plt.xlabel('Num. Episodes')
plt.ylabel('Score')
plt.savefig("scores_vs_episodes_linear.png", dpi=72)

# %%
t = np.arange(1,len(scores)+1)
plt.semilogy(t, scores, color="blue", linewidth=2.5, linestyle="-")
plt.xlabel('Num. Episodes')
plt.ylabel('Score')
plt.savefig("scores_vs_episodes_semilogy.png", dpi=72)
