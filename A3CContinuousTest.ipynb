# %%
# %matplotlib notebook

#Hack necessary for importing code in parent directories
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import ReinforcementLearning.A3C as A3C
# Out:
# /Users/sralimo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/sralimo/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/sralimo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/sralimo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# ...

# %%
from ContsMountainCarProblem import \
    getObservationShape, getActionShape, NONE_STATE, getEnv, build_model

A3C.getObservationShape = getObservationShape
A3C.getActionShape = getActionShape
A3C.NONE_STATE = NONE_STATE
A3C.build_model = build_model
A3C.getEnv = getEnv

A3C.CONTS_ACTIONS = True
A3C.SIGMA = 0.1
A3C.GRADIENT_CLIP = 5
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
A3C.run(False)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
#from ReinforcementLearning.A3C import fig, update_line1, update_line2, update_line3
from ReinforcementLearning.A3C import fig, plots, update_line
import matplotlib.animation as animation

update0 = lambda _ : update_line(0)
line_ani0 = animation.FuncAnimation(fig, update0, interval = 3000, blit=True)
update1 = lambda _ : update_line(1)
line_ani1 = animation.FuncAnimation(fig, update1, interval = 3000, blit=True)
update2 = lambda _ : update_line(2)
line_ani2 = animation.FuncAnimation(fig, update2, interval = 3000, blit=True)
update3 = lambda _ : update_line(3)
line_ani3 = animation.FuncAnimation(fig, update3, interval = 3000, blit=True)
update4 = lambda _ : update_line(4)
line_ani4 = animation.FuncAnimation(fig, update4, interval = 3000, blit=True)
update5 = lambda _ : update_line(5)
line_ani5 = animation.FuncAnimation(fig, update5, interval = 3000, blit=True)
update6 = lambda _ : update_line(6)
line_ani6 = animation.FuncAnimation(fig, update6, interval = 3000, blit=True)
update7 = lambda _ : update_line(7)
line_ani7 = animation.FuncAnimation(fig, update7, interval = 3000, blit=True)


fig.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
